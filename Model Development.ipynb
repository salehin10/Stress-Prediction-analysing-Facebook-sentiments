# %% [markdown]
# # Stress Prediction - Model Development

# %% [markdown]
# #### package imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
from google.colab import drive
from sklearn.model_selection import train_test_split 
from sklearn.metrics import r2_score

# %% [markdown]
# ### import file from drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Stress Prediction M2/selected_features.csv')
# #remove dance and fashion variables
# df.drop(['dance', 'fashion'], axis=1, inplace=True)
# df.head()
# Out:
#    pss_score     help  pride  ...       war      poor      pain
# 0         14  0.00000    0.0  ...  0.000000  0.000000  0.000000
# 1         15  0.00641    0.0  ...  0.003205  0.000000  0.000000
# 2         15  0.00641    0.0  ...  0.003205  0.000000  0.000000
# 3         22  0.00000    0.0  ...  0.000000  0.001449  0.002899
# 4         20  0.00000    0.0  ...  0.000000  0.000000  0.000000
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Multiple Linear Regression

# %%
# from sklearn.linear_model import LinearRegression
# Z = df[['help', 'pride', 'suffering', 'journalism','blue_collar_job','reading','anonymity','war','poor','pain']]
# lm = LinearRegression()
# lm.fit(Z, df['pss_score'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# print('the Intercept is ', lm.intercept_)
# Out:
# the Intercept is  15.999999999999996

# %%
# print('the coefficients are', lm.coef_)
# Out:
# the coefficients are [   33.14974961   216.80952689  1323.00059203  -352.32951916
#    817.3782607   1059.9999735  -1909.59960341  -378.29951918
#    915.62183232   835.29893605]

# %%
# print('The R-square is: ', lm.score(Z, df['pss_score']))
# Out:
# The R-square is:  0.9165613147914032

# %%
# from sklearn.metrics import mean_squared_error
# Y_predict_multifit = lm.predict(Z)
# print('The mean square error of price and predicted value is: ', mean_squared_error(df['pss_score'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value is:  2.1818181818181817

# %% [markdown]
# **Correction**

# %%
x = df.drop(['dance', 'fashion'], axis=1, inplace=True).values
y = df['pss_score'].values

#spliting dataset

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .20, random_state = 0)

#Training dataset
model = LinearRegression()
model.fit=(x_train, y_train)

#Testing/Predicting dataset
y_pred = model.predict(x_test)

#Determining R2 score to evalute our model 
r2_score(y_test,y_pred)

# %% [markdown]
# **Result data visualization**

# %%
plot.figure(fisize(15,10))
plot.scatter(y_test,y_pred)
plt.plot(x_test, reg.predict(x_test), color='maroon', label= ' Predicted Regression line')
plot.xlabel('Actual')
plot.ylabel('Predicted')
plot.title('Actual vs Predicted')
